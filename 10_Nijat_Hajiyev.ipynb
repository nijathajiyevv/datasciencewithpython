# %% [markdown]
# # Police Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from plotly import __version__
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
import cufflinks as cf
init_notebook_mode(connected=True)
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
# ...

# %%
data1 = pd.read_csv(r'C:\Users\nijat\Desktop\PYTHON - KURS\Ders 9\police.csv')

# %%
data1
# Out:
#         stop_date stop_time  county_name driver_gender  driver_age_raw  \
# 0        1.2.2005      1:55          NaN             M          1985.0
# 1       1.18.2005      8:15          NaN             M          1965.0
# 2       1.23.2005     23:15          NaN             M          1972.0
# 3       2.20.2005     17:15          NaN             M          1986.0
# 4       3.14.2005     10:00          NaN             F          1984.0
# ...           ...       ...          ...           ...             ...
# 91736  12.31.2015     20:27          NaN             M          1986.0
# 91737  12.31.2015     20:35          NaN             F          1982.0
# 91738  12.31.2015     20:45          NaN             M          1992.0
# 91739  12.31.2015     21:42          NaN             M          1993.0
# 91740  12.31.2015     22:46          NaN             M          1959.0
#
#        driver_age driver_race                   violation_raw  \
# ...

# %%
data1.describe(include='all')
# Out:
#         stop_date stop_time  county_name driver_gender  driver_age_raw  \
# count       91741     91741          0.0         86406    86414.000000
# unique       3768      1436          NaN             2             NaN
# top     1.11.2012     11:00          NaN             M             NaN
# freq           69       323          NaN         62895             NaN
# mean          NaN       NaN          NaN           NaN     1970.491228
# std           NaN       NaN          NaN           NaN      110.914909
# min           NaN       NaN          NaN           NaN        0.000000
# 25%           NaN       NaN          NaN           NaN     1967.000000
# 50%           NaN       NaN          NaN           NaN     1980.000000
# 75%           NaN       NaN          NaN           NaN     1987.000000
# max           NaN       NaN          NaN           NaN     8801.000000
#
#           driver_age driver_race violation_raw violation search_conducted  \
# ...

# %%
sns.boxplot(data=data1['driver_age'],orient='h')
# Out:
# <AxesSubplot:>

# %%
# descriptive statistikadan outlier kimi gorduyunuz numeric musteqil deyishenler uzerinde
# boxplot qurun ve outlier-larin hansi hisselerde olduqunu mueyyen edin.

# %%
data1.dtypes
# Out:
# stop_date              object
# stop_time              object
# county_name           float64
# driver_gender          object
# driver_age_raw        float64
# driver_age            float64
# driver_race            object
# violation_raw          object
# violation              object
# search_conducted         bool
# search_type            object
# stop_outcome           object
# is_arrested            object
# stop_duration          object
# drugs_related_stop       bool
# dtype: object

# %%
data1.isnull().sum()
# Out:
# stop_date                 0
# stop_time                 0
# county_name           91741
# driver_gender          5335
# driver_age_raw         5327
# driver_age             5621
# driver_race            5333
# violation_raw          5333
# violation              5333
# search_conducted          0
# search_type           88545
# stop_outcome           5333
# is_arrested            5333
# stop_duration          5333
# drugs_related_stop        0
# dtype: int64

# %%
data1.drop('county_name',axis=1,inplace=True)

# %%
data1.drop('search_type',axis=1,inplace=True)

# %%
# drop several columns together

# data1.drop(['county_name','search_type'], axis=1, inplace=True)

# %%
data1[['driver_gender', 'driver_race']] = data1[['driver_gender', 'driver_race']].fillna('Unknown')

# %%
data1['driver_age'].fillna(value=data1['driver_age'].mean(), inplace=True)

# %%
data1.isnull().sum()
# Out:
# stop_date                0
# stop_time                0
# driver_gender            0
# driver_age_raw        5327
# driver_age               0
# driver_race              0
# violation_raw         5333
# violation             5333
# search_conducted         0
# stop_outcome          5333
# is_arrested           5333
# stop_duration         5333
# drugs_related_stop       0
# dtype: int64

# %%
violations = data1["violation_raw"].value_counts()
violations
# Out:
# Speeding                            48463
# Other Traffic Violation             16224
# Equipment/Inspection Violation      11020
# Registration Violation               3432
# Seatbelt Violation                   2952
# Special Detail/Directed Patrol       2455
# Call for Service                     1298
# Violation of City/Town Ordinance      211
# Motorist Assist/Courtesy              203
# APB                                    79
# Suspicious Person                      56
# Warrant                                15
# Name: violation_raw, dtype: int64

# %%
violations.plot.bar()
# Out:
# <AxesSubplot:>

# %%
#violations datasinda olan qayda pozuntularini barplot ile ashaqidaki kimi gosterin

# %%
data1.stop_outcome.value_counts()
#data1['stop_outcome'].value_counts()
# Out:
# Citation            77006
# Warning              5294
# Arrest Driver        2571
# N/D                   590
# No Action             589
# Arrest Passenger      358
# Name: stop_outcome, dtype: int64

# %%
sns.barplot(x='stop_outcome',y='driver_age',data=data1,estimator=np.average)
# Out:
# <AxesSubplot:xlabel='stop_outcome', ylabel='driver_age'>

# %%
#stop outcome sutunuanda olan qayda pozuntularinin driver_age sutunundan olan asilliqin
# barplot ile ashaqidaki kimi gosterin. estimater olaraq average istifade edin

# %%
arrested = data1[data1['stop_outcome'] == 'Arrest Driver']

# %%
arrested
# Out:
#         stop_date stop_time driver_gender  driver_age_raw  driver_age  \
# 3       2.20.2005     17:15             M          1986.0        19.0
# 22       8.8.2005      2:09             M          1955.0        50.0
# 24      8.28.2005      1:00             M          1979.0        26.0
# 31      9.28.2005      6:20             M          1982.0        23.0
# 40      10.1.2005      0:00             M          1988.0        17.0
# ...           ...       ...           ...             ...         ...
# 91297   12.8.2015      1:30             M          1994.0        21.0
# 91386  12.12.2015     20:00             M          1973.0        42.0
# 91471  12.16.2015     14:52             M          1975.0        40.0
# 91625  12.26.2015     23:18             M          1969.0        46.0
# 91628  12.27.2015      0:27             M          1987.0        28.0
#
#       driver_race                   violation_raw            violation  \
# ...

# %%
arrested.describe(include='all')
# Out:
#         stop_date stop_time driver_gender  driver_age_raw   driver_age  \
# count        2571      2571          2571     2571.000000  2571.000000
# unique       1755      1036             2             NaN          NaN
# top     12.5.2005     23:30             M             NaN          NaN
# freq            6        15          2103             NaN          NaN
# mean          NaN       NaN           NaN     1976.223648    31.939730
# std           NaN       NaN           NaN       56.174438    10.335196
# min           NaN       NaN           NaN        0.000000    15.000000
# 25%           NaN       NaN           NaN     1971.000000    24.000000
# 50%           NaN       NaN           NaN     1980.000000    29.000000
# 75%           NaN       NaN           NaN     1986.000000    38.000000
# max           NaN       NaN           NaN     2006.000000    79.000000
#
#        driver_race            violation_raw         violation  \
# ...

# %%
sns.countplot(x=data1["driver_gender"])
# Out:
# <AxesSubplot:xlabel='driver_gender', ylabel='count'>

# %%
sns.countplot(x=arrested["driver_gender"])
# Out:
# <AxesSubplot:xlabel='driver_gender', ylabel='count'>

# %%
# driver gender sutununu countplot ile gosterin

# %%
male
# Out:
#         stop_date stop_time driver_gender  driver_age_raw  driver_age  \
# 0        1.2.2005      1:55             M          1985.0        20.0
# 1       1.18.2005      8:15             M          1965.0        40.0
# 2       1.23.2005     23:15             M          1972.0        33.0
# 3       2.20.2005     17:15             M          1986.0        19.0
# 5       3.23.2005      9:45             M          1982.0        23.0
# ...           ...       ...           ...             ...         ...
# 91735  12.31.2015     20:25             M          1992.0        23.0
# 91736  12.31.2015     20:27             M          1986.0        29.0
# 91738  12.31.2015     20:45             M          1992.0        23.0
# 91739  12.31.2015     21:42             M          1993.0        22.0
# 91740  12.31.2015     22:46             M          1959.0        56.0
#
#       driver_race                   violation_raw         violation  \
# ...

# %%
# male datasinda driver_age-i histogram ile gosterin.
# fiqurun title-i , x ve y oxlarinin title-lari qeyd olunsun

# %%
plt.figure(figsize=(8, 6))
male = data1[data1["driver_gender"] == "M"]
plt.hist(x = male['driver_age']) 
plt.xlabel('age')
plt.ylabel('Frequency')
plt.title('Age of men caught by the police')
plt.show()

# %%
sns.histplot(data = male, x = 'driver_age', bins = 15)
# Out:
# <AxesSubplot:xlabel='driver_age', ylabel='Count'>

# %%
male["driver_age"].mean(a)
# Out:
# 34.53582618529012

# %%
oldest_male = male[male["driver_age"] == male["driver_age"].max()]
oldest_male
# Out:
#        stop_date stop_time driver_gender  driver_age_raw  driver_age  \
# 75037  2.14.2014     10:21             M          1920.0        94.0
#
#       driver_race            violation_raw         violation  \
# 75037       White  Other Traffic Violation  Moving violation
#
#        search_conducted stop_outcome is_arrested stop_duration  \
# 75037             False     Citation       False      0-15 Min
#
#        drugs_related_stop
# 75037               False

# %%
arrested_most = data1[data1["stop_outcome"] == "Arrest Driver"]

# %%
arrested_most["violation"].value_counts()
# Out:
# Moving violation       813
# Speeding               583
# Equipment              491
# Other                  327
# Registration/plates    302
# Seat belt               55
# Name: violation, dtype: int64

# %% [markdown]
# # Second Data
#
# ## house.xlsx

# %%
import pandas as pd
import numpy as np
import seaborn as sns
sns.set()

data2 = pd.read_excel(r'C:\Users\nijat\Desktop\PYTHON - KURS\Ders 9\house.xlsx')

# %%
data2
# Out:
#      Home   Price  SqFt  Bedrooms  Bathrooms  Offers Brick Neighborhood
# 0       1  114300  1790         2          2       2    No         East
# 1       2  114200  2030         4          2       3    No         East
# 2       3  114800  1740         3          2       1    No         East
# 3       4   94700  1980         3          2       3    No         East
# 4       5  119800  2130         3          3       3    No         East
# ..    ...     ...   ...       ...        ...     ...   ...          ...
# 123   124  119700  1900         3          3       3   Yes         East
# 124   125  147900  2160         4          3       3   Yes         East
# 125   126  113500  2070         2          2       2    No        North
# 126   127  149900  2020         3          3       1    No         West
# 127   128  124600  2250         3          3       4    No        North
#
# [128 rows x 8 columns]

# %%
data2.describe(include='all')
# Out:
#               Home          Price         SqFt    Bedrooms   Bathrooms  \
# count   128.000000     128.000000   128.000000  128.000000  128.000000
# unique         NaN            NaN          NaN         NaN         NaN
# top            NaN            NaN          NaN         NaN         NaN
# freq           NaN            NaN          NaN         NaN         NaN
# mean     64.500000  130427.343750  2000.937500    3.023438    2.445312
# std      37.094474   26868.770371   211.572431    0.725951    0.514492
# min       1.000000   69100.000000  1450.000000    2.000000    2.000000
# 25%      32.750000  111325.000000  1880.000000    3.000000    2.000000
# 50%      64.500000  125950.000000  2000.000000    3.000000    2.000000
# 75%      96.250000  148250.000000  2140.000000    3.000000    3.000000
# max     128.000000  211200.000000  2590.000000    5.000000    4.000000
#
#             Offers Brick Neighborhood
# count   128.000000   128          128
# ...

# %%
sns.boxplot(data=data2['Price'],orient='h')
# Out:
# <AxesSubplot:>

# %%
# descriptive statistikadan outlier kimi gorduyunuz numeric musteqil deyishenler uzerinde
# boxplot qurun ve outlier-larin hansi hisselerde olduqunu mueyyen edin.

# %%
data2.isnull().sum()
# Out:
# Home            0
# Price           0
# SqFt            0
# Bedrooms        0
# Bathrooms       0
# Offers          0
# Brick           0
# Neighborhood    0
# dtype: int64

# %%
sns.pairplot(data2,hue='Brick',palette='colorblind')

# %%
# Butun data-ni pairplot edin. reng colorblind olsun ve Brick sutunu uzre asilliq gorunsun (hue metodu)

# %%
# Butun sutunlari plotly kitabxanasindan istifade ederek boxplot-lar uzre gosterin


data2.boxplot()
# Out:
# <AxesSubplot:>

# %%
data2.columns
# Out:
# Index(['Home', 'Price', 'SqFt', 'Bedrooms', 'Bathrooms', 'Offers', 'Brick',
#        'Neighborhood'],
#       dtype='object')

# %%
sns.boxplot(x="Bedrooms", y="Price", data=data2,palette='rainbow')
# Out:
# <AxesSubplot:xlabel='Bedrooms', ylabel='Price'>

# %%
# Price ve bedroom sutunlarindan istifade ederek ashaqidaki boxplotu qurun

# %%
data2.corr()
# Out:
#                Home     Price      SqFt  Bedrooms  Bathrooms    Offers
# Home       1.000000  0.108190  0.168553 -0.068568   0.127694 -0.053597
# Price      0.108190  1.000000  0.552982  0.525926   0.523258 -0.313636
# SqFt       0.168553  0.552982  1.000000  0.483807   0.522745  0.336923
# Bedrooms  -0.068568  0.525926  0.483807  1.000000   0.414556  0.114271
# Bathrooms  0.127694  0.523258  0.522745  0.414556   1.000000  0.143793
# Offers    -0.053597 -0.313636  0.336923  0.114271   0.143793  1.000000

# %%
sns.heatmap(data2.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
# Heatmap istifade edib correlation qurun, xanalar uzerinde reqemler qeyd olunsun
# Out:
# <AxesSubplot:>

# %%
data2.columns
# Out:
# Index(['Home', 'Price', 'SqFt', 'Bedrooms', 'Bathrooms', 'Offers', 'Brick',
#        'Neighborhood'],
#       dtype='object')

# %%
data3 = data2[(data2['Price']<=100000) & (data2['SqFt']>=1500)]
data3
# Out:
#      Home  Price  SqFt  Bedrooms  Bathrooms  Offers Brick Neighborhood
# 3       4  94700  1980         3          2       3    No         East
# 17     18  83600  1990         3          3       4    No        North
# 22     23  91700  1690         3          2       3    No        North
# 27     28  99300  1700         3          2       2    No         East
# 28     29  69100  1600         2          2       3    No        North
# 47     48  90300  2050         3          2       6    No        North
# 51     52  91100  1860         2          2       3    No        North
# 54     55  81300  1650         3          2       3    No        North
# 68     69  93600  2140         3          2       4    No        North
# 84     85  90500  1520         2          2       3    No        North
# 89     90  97800  2010         2          2       4    No        North
# 104   105  82300  1910         3          2       4    No         East

# %%
data3['house_type']=np.where((data3['Bedrooms']>=3)&(data3['Bathrooms']>=3),'house','apartment')
data3
# Out:
#      Home  Price  SqFt  Bedrooms  Bathrooms  Offers Brick Neighborhood  \
# 3       4  94700  1980         3          2       3    No         East
# 17     18  83600  1990         3          3       4    No        North
# 22     23  91700  1690         3          2       3    No        North
# 27     28  99300  1700         3          2       2    No         East
# 28     29  69100  1600         2          2       3    No        North
# 47     48  90300  2050         3          2       6    No        North
# 51     52  91100  1860         2          2       3    No        North
# 54     55  81300  1650         3          2       3    No        North
# 68     69  93600  2140         3          2       4    No        North
# 84     85  90500  1520         2          2       3    No        North
# 89     90  97800  2010         2          2       4    No        North
# 104   105  82300  1910         3          2       4    No         East
#
#     house_type
# 3    apartment
# ...

# %%
data3['Offers_type'] = np.where(data3.Offers >= 4, 'good', 
         (np.where(data3.Offers <= 2, 'bad', 'normal')))

data3
# Out:
#      Home  Price  SqFt  Bedrooms  Bathrooms  Offers Brick Neighborhood  \
# 3       4  94700  1980         3          2       3    No         East
# 17     18  83600  1990         3          3       4    No        North
# 22     23  91700  1690         3          2       3    No        North
# 27     28  99300  1700         3          2       2    No         East
# 28     29  69100  1600         2          2       3    No        North
# 47     48  90300  2050         3          2       6    No        North
# 51     52  91100  1860         2          2       3    No        North
# 54     55  81300  1650         3          2       3    No        North
# 68     69  93600  2140         3          2       4    No        North
# 84     85  90500  1520         2          2       3    No        North
# 89     90  97800  2010         2          2       4    No        North
# 104   105  82300  1910         3          2       4    No         East
#
#     house_type Offers_type
# ...

# %%
data_final = data2.loc[:,['SqFt','Bedrooms','Bathrooms','Price']]
data_final = data2[['SqFt','Bedrooms','Bathrooms','Price']]

# %%
data_final
# Out:
#      SqFt  Bedrooms  Bathrooms   Price
# 0    1790         2          2  114300
# 1    2030         4          2  114200
# 2    1740         3          2  114800
# 3    1980         3          2   94700
# 4    2130         3          3  119800
# ..    ...       ...        ...     ...
# 123  1900         3          3  119700
# 124  2160         4          3  147900
# 125  2070         2          2  113500
# 126  2020         3          3  149900
# 127  2250         3          3  124600
#
# [128 rows x 4 columns]
