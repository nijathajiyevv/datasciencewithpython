# %% [markdown]
# # Homework

# %% [markdown]
# ### Assignment 1
#
# Print Mark's salary from the my_list object shown below.
#
# my_list = [{'Tim': 20000, 'Mark': 12000}, ['car', 'laptop', 'TV']]

# %%
my_list = [{'Tim': 20000, 'Mark': 12000}, ['car', 'laptop', 'TV']]

print(my_list[0]['Mark'])
# Out:
# 12000

# %% [markdown]
# ### Assignment 2
#
# In the list shown below, replace the letter m with the letter x
# and replace the word 'social' with the word 'network'. Then print my_list.
#
# my_list = [(1, 2), (3, 4), (['c', 'd', 'a', 'm'], [3, 9, 4, 12], 4), 'social', 42]
#
# Output should be like below:

# %% [markdown]
# ![Screenshot%202022-12-08%20154520.png](attachment:Screenshot%202022-12-08%20154520.png)

# %%
my_list = [(1, 2), (3, 4), (['c', 'd', 'a', 'm'], [3, 9, 4, 12], 4), 'social', 42]

my_list[2][0][3] = 'x'
my_list[3] = 'network'
print(my_list)
# Out:
# [(1, 2), (3, 4), (['c', 'd', 'a', 'x'], [3, 9, 4, 12], 4), 'network', 42]

# %% [markdown]
# ### Assignment 3
#
# Create a dataframe

# %% [markdown]
# ![Screenshot%202022-12-08%20154724.png](attachment:Screenshot%202022-12-08%20154724.png)

# %%
import pandas as pd
import numpy as np
data = {'Bankın adı': ['ABB','Accessbank','AFB Bank','Azərbaycan Sənaye Bankı',
                       'Azər-Türk Bank','Bank Avrasiya','Bank of Baku','Bank BTB',
                      'Bank Respublika','Bank VTB','EXpressbank','Xalqbank',
                      'Kapital Bank','Naxçıvanbank','Yelo Bank','Paşa Bank',
                      'Rabitəbank','Turanbank','Unibank','Yapı Kredi Bank','Ziraat Bank',],
        'Məbləğ AZN': ['15 000-dək', '500 - 30 000', '300 - 30 000', '500 - 20 000', '300 - 30 000',
                       '50 000 - dək','300 - 30 000', '30 000 - dək', '500 - 30 000', '300 - 35 000', 
                      '300 - 30 000', '500 - 100 000', '30 000 - dək', '25 000 - dək', '300 - 30 000', 
                      '-', '30 000 - dək', '500 - dən başlayaraq', '300 - 20 000', '300 - dən başlayaraq', '250 000-dək'  ],
        'Müddət': ['48 ayadək', '6 - 48 ay', '3 - 48 ay', '36 ay', '3 - 48 ay', 
                  '60 ay', '3 - 48 ay', '36 ayadək', '6 - 48 ay', '6 - 60 ay',
                  '3 - 60 ay', '24 - 72 ay', '60 ayadək','36 ayadək',
                  '6 - 48 ay', '48 ayadək', '36 ayadək', '48 ay',
                  '60 ayadək', '3 - 36 ay', '48 ayadək'],
           'Faiz dərəcəsi' : ['18%','14%','14%','15-21%','14-17.5%',
                             '16%','16%','15%','15%','16.5%','13.22%',
                             '12-16%','15%','17%','14%','21-29%','14%','14.7%',
                             '16%','19.90%','16%',],
           'Komissiya': ['1%','0-1%','1-2%','1%','0-1%','1%','1%',
                        '0%','0-1%','0%','0%','0.1%','0%','0.9%',
                        '0-1%','1%','1%','0-3%','1-3.5%','1.65%','1%',]}
  
# Create DataFrame
df = pd.DataFrame(data)
df.index = np.arange(1, len(df) + 1)
df
# Out:
#                  Bankın adı            Məbləğ AZN      Müddət Faiz dərəcəsi  \
# 1                       ABB            15 000-dək   48 ayadək           18%
# 2                Accessbank          500 - 30 000   6 - 48 ay           14%
# 3                  AFB Bank          300 - 30 000   3 - 48 ay           14%
# 4   Azərbaycan Sənaye Bankı          500 - 20 000       36 ay        15-21%
# 5            Azər-Türk Bank          300 - 30 000   3 - 48 ay      14-17.5%
# 6             Bank Avrasiya          50 000 - dək       60 ay           16%
# 7              Bank of Baku          300 - 30 000   3 - 48 ay           16%
# 8                  Bank BTB          30 000 - dək   36 ayadək           15%
# 9           Bank Respublika          500 - 30 000   6 - 48 ay           15%
# 10                 Bank VTB          300 - 35 000   6 - 60 ay         16.5%
# 11              EXpressbank          300 - 30 000   3 - 60 ay        13.22%
# ...
